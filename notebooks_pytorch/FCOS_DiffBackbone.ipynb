# %%
# Install dependencies and 
# !pip install albumentations==0.4.6
# !pip install pycocotools --quiet

# Clone TorchVision repo and copy helper files
# !git clone https://github.com/pytorch/vision.git
# %cd vision
# !git checkout v0.3.0
# %cd ..
# !copy ./vision/references/detection/utils.py .
# !copy ./vision/references/detection/transforms.py .
# !copy ./vision/references/detection/coco_eval.py .
# !copy ./vision/references/detection/engine.py .
# !copy ./vision/references/detection/coco_utils.py .

# %%
# basic python and ML Libraries
import os
import random
import numpy as np
import pandas as pd
import math

# for ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# We will be reading images using OpenCV
import cv2

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchvision libraries
import torch
import torchvision
import torch.nn as nn
from torchvision import transforms as torchtrans
from torchvision.models.detection.fcos import FCOSHead  

# helper libraries
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

import xml.etree.ElementTree as ET

# %%
files_dir = r"D:\Abdallah\Venvs\tvenv\notebook\imgs"

class NeutrophilDataset(torch.utils.data.Dataset):
    def __init__(self, files_dir, transforms=None):
        self.transforms = transforms
        self.files_dir = files_dir
        
        #sorting images
        #to get images, the last 4 characters are checked for ".jpg"
        self.imgs = [image for image in sorted(os.listdir(files_dir)) if image[-4:]=='.jpg']
        
        #classes: 0 index is reserve for background
        self.classes = [_, 'neutrophil']
        
    def __getitem__(self, idx):
        img_name = self.imgs[idx]
        image_path = os.path.join(r"{}".format(self.files_dir), img_name)
        
        #reading images and converting them to correct size, color and format
        img = cv2.imread(image_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        
        #normalize
        img_res = img_rgb / 255.0
        
        #annotation xml files
        annot_filename = img_name[:-4] + ".xml"
        annot_file_path = os.path.join(self.files_dir, annot_filename)
        
        boxes = []
        labels = []
        
        tree = ET.parse(annot_file_path)
        root = tree.getroot()
        
        for coordinate in root.findall('object'):
            xmin = int(coordinate[4][0].text)
            ymin = int(coordinate[4][1].text)
            xmax = int(coordinate[4][2].text)
            ymax = int(coordinate[4][3].text)
            
            boxes.append([xmin, ymin, xmax, ymax])
            
            #append 0's for the lable because we only have neutrophil class
            labels.append(1)

        #Converting boxes to tensors
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        
        #getting areas of the boxes (Y * X, W * H)
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        
        #suppose all instances are not crowd (overlapping)
        iscrowd = torch.zeros((boxes.shape[0]), dtype=torch.int64)
        
        labels = torch.as_tensor(labels, dtype=torch.int64)
        
        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd
        
        image_id = torch.tensor([idx])
        target["image_id"] = image_id
        
        if self.transforms:
            sample = self.transforms(image = img_res,
                                     bboxes = target["boxes"],
                                     labels = labels)
            img_res = sample["image"]
            target["boxes"] = torch.Tensor(sample['bboxes'])
        
        return img_res, target
    
    def __len__ (self):
        return len(self.imgs)
    
#check dataset
dataset = NeutrophilDataset(files_dir)
print("Length of dataset:", len(dataset), "\n")
    
#getting the image and target for a test index
img, target = dataset[50]
print("Image shape:", img.shape)
print("Label example:", target)
# Out:
# Length of dataset: 155
#
# Image shape: (1024, 1024, 3)
# Label example: {'boxes': tensor([[491., 699., 500., 705.],
#         [644., 770., 655., 778.],
#         [216., 791., 228., 800.],
#         [101., 422., 113., 431.]]), 'labels': tensor([1, 1, 1, 1]), 'area': tensor([ 54.,  88., 108., 108.]), 'iscrowd': tensor([0, 0, 0, 0]), 'image_id': tensor([50])}

# %% [markdown]
# **CHECKS TO SEE FOR EMPTY BB**

# %%
#use enumerate and then do: if len(box) = 0, counter += 1, print(counter)
empty_boxes = 0
boxes = target["boxes"]
for box in boxes:
    if len(box) == 0:
        empty_boxes +=1
print("Number of empty bounding boxes:", empty_boxes)
# Out:
# Number of empty bounding boxes: 0

# %%
#function to visualize the bounding boxes to make sure im making the dataset properly
def plot_img_box(img, target):
    #plot the image and bb
    #bb def: xmin ymin width height
    fig, a = plt.subplots(1,1)
    fig.set_size_inches(5,5)
    a.imshow(img)
    for box in (target["boxes"]):
        x, y, width, height = box[0], box[1], box[2] - box[0], box[3] - box[1]
        rect = patches.Rectangle(
        (x, y),
        width, height,
        linewidth = 1,
        edgecolor = 'b',
        facecolor = 'none'
        )
        #overlay bb ontop of image
        a.add_patch(rect)
    plt.show()
    
#plotting the img with bb
img, target = dataset[52]
num_bb = len(target['boxes'])
print(f'Ground Truth Neutrophil Count: {num_bb}\n')
plot_img_box(img, target)
# Out:
# Ground Truth Neutrophil Count: 7

# %%
# Send train=True for training transforms and False for val/test transforms
def get_transform(train):
  if train:
    return A.Compose(
      [
        A.HorizontalFlip(p=0.25),
        A.Rotate(p=0.25),
        A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.20),
        A.VerticalFlip(p=0.20),
        A.RandomSizedBBoxSafeCrop(height=512, width=512, p=0.25),
        A.GaussianBlur(blur_limit=3, p=0.10),
        A.JpegCompression(p=0.10),
        A.CoarseDropout(max_holes=15, max_height=10, max_width=10, p=0.15),
        #elastic transform, vertical flip, bboxsaferandomcrop, verticallip, gaussian blur   
        #ToTensorV2 converts image to pytorch tensor without div by 255
        ToTensorV2(p=1.0) 
      ],
      bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']}
    )
  else:
    return A.Compose(
      [ToTensorV2(p=1.0)],
      bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']}
    )

# %%
#using our neutrophil dataset and defined transforms from above
dataset = NeutrophilDataset(files_dir, transforms=get_transform(train=True))
dataset_test = NeutrophilDataset(files_dir, transforms=get_transform(train=False))

#split test and train
torch.manual_seed(1)
indices = torch.randperm(len(dataset)).tolist()

test_split = 0.2
tsize = int(len(dataset)*test_split)
dataset = torch.utils.data.Subset(dataset, indices[:-tsize])
dataset_test = torch.utils.data.Subset(dataset_test, indices[-tsize:])

#define training and val dataloaders
data_loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=16,
    shuffle=True,
    collate_fn=utils.collate_fn
)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test,
    batch_size=16,
    shuffle=False,
    collate_fn=utils.collate_fn
)

# %%
#load pretrained fcos model
def get_object_detection_model(num_classes):
    
    #load the pretrained model
    model = torchvision.models.detection.fcos_resnet50_fpn(pretrained=True)
    
    #freeze backbone layers (higher level layers for more intricate object details)
    for param in model.backbone.features[:5].parameters():
        param.requires_grad = False

# %%
model = torchvision.models.detection.fcos_resnet50_fpn(pretrained=True)
dir(model)
# Out:
# ['T_destination',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_apply',
#  '_backward_hooks',
#  '_buffers',
#  '_call_impl',
#  '_forward_hooks',
#  '_forward_pre_hooks',
#  '_get_backward_hooks',
#  '_get_name',
#  '_has_warned',
#  '_is_full_backward_hook',
#  '_load_from_state_dict',
#  '_load_state_dict_post_hooks',
#  '_load_state_dict_pre_hooks',
#  '_maybe_warn_non_full_backward_hook',
#  '_modules',
#  '_named_members',
#  '_non_persistent_buffers_set',
#  '_parameters',
#  '_register_load_state_dict_pre_hook',
#  '_register_state_dict_hook',
#  '_replicate_for_data_parallel',
#  '_save_to_state_dict',
#  '_slow_forward',
#  '_state_dict_hooks',
#  '_version',
#  'add_module',
#  'anchor_generator',
#  'apply',
#  'backbone',
#  'bfloat16',
#  'box_coder',
#  'buffers',
#  'center_sampling_radius',
#  'children',
#  'compute_loss',
#  'cpu',
#  'cuda',
#  'detections_per_img',
#  'double',
#  'dump_patches',
#  'eager_outputs',
#  'eval',
#  'extra_repr',
#  'float',
#  'forward',
#  'get_buffer',
#  'get_extra_state',
#  'get_parameter',
#  'get_submodule',
#  'half',
#  'head',
#  'ipu',
#  'load_state_dict',
#  'modules',
#  'named_buffers',
#  'named_children',
#  'named_modules',
#  'named_parameters',
#  'nms_thresh',
#  'parameters',
#  'postprocess_detections',
#  'register_backward_hook',
#  'register_buffer',
#  'register_forward_hook',
#  'register_forward_pre_hook',
#  'register_full_backward_hook',
#  'register_load_state_dict_post_hook',
#  'register_module',
#  'register_parameter',
#  'requires_grad_',
#  'score_thresh',
#  'set_extra_state',
#  'share_memory',
#  'state_dict',
#  'to',
#  'to_empty',
#  'topk_candidates',
#  'train',
#  'training',
#  'transform',
#  'type',
#  'xpu',
#  'zero_grad']

# %% [markdown]
# **TRAIN SETUP**

# %%
#gpu training
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

num_classes = 2 #neutrophil (1) and background class (0)

model = get_object_detection_model(num_classes)
model.to(device)

#construct optim
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.0055, momentum=0.9, weight_decay=0.0001)

#learning rate scheduler to decrease lr by 10x every 3 epochs (not to overshoot minimum)
lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[75, 150, 200, 225], gamma=0.75)

# %% [markdown]
# **CHECK GPU**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)
# Out:
# cuda

# %% [markdown]
# **TRAINING**

# %%
num_epochs = 250

for epoch in range(num_epochs):
    #training at each epoch
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=1)
    #update lr
    lr_scheduler.step()
    #eval
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [0/8]  eta: 0:00:33  lr: 0.000790  loss: 2.6816 (2.6816)  classification: 1.1080 (1.1080)  bbox_regression: 0.8690 (0.8690)  bbox_ctrness: 0.7046 (0.7046)  time: 4.1761  data: 0.7662  max mem: 4011
# Epoch: [0]  [1/8]  eta: 0:00:18  lr: 0.001575  loss: 2.6816 (2.7041)  classification: 1.1080 (1.1080)  bbox_regression: 0.8690 (0.8913)  bbox_ctrness: 0.7046 (0.7047)  time: 2.6954  data: 0.7207  max mem: 4033
# Epoch: [0]  [2/8]  eta: 0:00:13  lr: 0.002360  loss: 2.6816 (2.6895)  classification: 1.1080 (1.0966)  bbox_regression: 0.8869 (0.8898)  bbox_ctrness: 0.7046 (0.7030)  time: 2.2326  data: 0.7348  max mem: 4052
# Epoch: [0]  [3/8]  eta: 0:00:09  lr: 0.003145  loss: 2.6603 (2.6490)  classification: 1.0738 (1.0741)  bbox_regression: 0.8690 (0.8748)  bbox_ctrness: 0.6996 (0.7002)  time: 1.9829  data: 0.7246  max mem: 4052
# Epoch: [0]  [4/8]  eta: 0:00:07  lr: 0.003930  loss: 2.6603 (2.6049)  classification: 1.0738 (1.0326)  bbox_regression: 0.8766 (0.8751)  bbox_ctrness: 0.6996 (0.6972)  time: 1.8503  data: 0.7347  max mem: 4061
# Epoch: [0]  [5/8]  eta: 0:00:05  lr: 0.004715  loss: 2.5276 (2.5516)  classification: 1.0063 (0.9931)  bbox_regression: 0.8690 (0.8652)  bbox_ctrness: 0.6918 (0.6933)  time: 1.7543  data: 0.7316  max mem: 4079
# Epoch: [0]  [6/8]  eta: 0:00:03  lr: 0.005500  loss: 2.6603 (2.5867)  classification: 1.0738 (1.0512)  bbox_regression: 0.8690 (0.8466)  bbox_ctrness: 0.6918 (0.6888)  time: 1.6897  data: 0.7357  max mem: 4079
# Epoch: [0]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 2.5276 (2.5538)  classification: 1.0063 (1.0452)  bbox_regression: 0.8295 (0.8259)  bbox_ctrness: 0.6853 (0.6827)  time: 1.5920  data: 0.7047  max mem: 4079
# Epoch: [0] Total time: 0:00:12 (1.5928 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:02  model_time: 0.5773 (0.5773)  evaluator_time: 0.0030 (0.0030)  time: 1.0234  data: 0.3861  max mem: 4079
# Test:  [1/2]  eta: 0:00:00  model_time: 0.3285 (0.4529)  evaluator_time: 0.0020 (0.0025)  time: 0.8650  data: 0.3626  max mem: 4079
# Test: Total time: 0:00:01 (0.8660 s / it)
# Averaged stats: model_time: 0.3285 (0.4529)  evaluator_time: 0.0020 (0.0025)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [1]  [0/8]  eta: 0:00:08  lr: 0.005500  loss: 2.5243 (2.5243)  classification: 1.2865 (1.2865)  bbox_regression: 0.5934 (0.5934)  bbox_ctrness: 0.6444 (0.6444)  time: 1.1153  data: 0.5771  max mem: 4079
# Epoch: [1]  [1/8]  eta: 0:00:07  lr: 0.005500  loss: 2.5243 (2.5591)  classification: 1.2865 (1.3251)  bbox_regression: 0.5905 (0.5920)  bbox_ctrness: 0.6395 (0.6420)  time: 1.0964  data: 0.5476  max mem: 4079
# Epoch: [1]  [2/8]  eta: 0:00:06  lr: 0.005500  loss: 2.5392 (2.5524)  classification: 1.3472 (1.3325)  bbox_regression: 0.5905 (0.5888)  bbox_ctrness: 0.6395 (0.6312)  time: 1.1293  data: 0.5868  max mem: 4079
# Epoch: [1]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 2.5243 (2.5166)  classification: 1.2865 (1.3062)  bbox_regression: 0.5824 (0.5837)  bbox_ctrness: 0.6133 (0.6267)  time: 1.1280  data: 0.5876  max mem: 4079
# Epoch: [1]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 2.5243 (2.4643)  classification: 1.2865 (1.2614)  bbox_regression: 0.5824 (0.5804)  bbox_ctrness: 0.6133 (0.6225)  time: 1.1536  data: 0.6147  max mem: 4079
# Epoch: [1]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 2.4090 (2.3965)  classification: 1.2272 (1.1983)  bbox_regression: 0.5730 (0.5792)  bbox_ctrness: 0.6096 (0.6190)  time: 1.1361  data: 0.5976  max mem: 4079
# Epoch: [1]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 2.4090 (2.3384)  classification: 1.2272 (1.1313)  bbox_regression: 0.5824 (0.5810)  bbox_ctrness: 0.6133 (0.6261)  time: 1.1239  data: 0.5858  max mem: 4079
# Epoch: [1]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 2.2550 (2.3176)  classification: 1.0823 (1.1103)  bbox_regression: 0.5730 (0.5800)  bbox_ctrness: 0.6133 (0.6273)  time: 1.0925  data: 0.5711  max mem: 4079
# Epoch: [1] Total time: 0:00:08 (1.0934 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:01  model_time: 0.5528 (0.5528)  evaluator_time: 0.0030 (0.0030)  time: 0.9609  data: 0.3751  max mem: 4079
# Test:  [1/2]  eta: 0:00:00  model_time: 0.3078 (0.4303)  evaluator_time: 0.0030 (0.0030)  time: 0.8228  data: 0.3601  max mem: 4079
# Test: Total time: 0:00:01 (0.8238 s / it)
# Averaged stats: model_time: 0.3078 (0.4303)  evaluator_time: 0.0030 (0.0030)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [2]  [0/8]  eta: 0:00:08  lr: 0.005500  loss: 1.9321 (1.9321)  classification: 0.6909 (0.6909)  bbox_regression: 0.5974 (0.5974)  bbox_ctrness: 0.6438 (0.6438)  time: 1.1242  data: 0.6071  max mem: 4079
# Epoch: [2]  [1/8]  eta: 0:00:08  lr: 0.005500  loss: 1.9321 (1.9367)  classification: 0.6909 (0.7304)  bbox_regression: 0.5651 (0.5812)  bbox_ctrness: 0.6063 (0.6251)  time: 1.1455  data: 0.6176  max mem: 4087
# Epoch: [2]  [2/8]  eta: 0:00:07  lr: 0.005500  loss: 1.9413 (1.9678)  classification: 0.7698 (0.7622)  bbox_regression: 0.5970 (0.5865)  bbox_ctrness: 0.6072 (0.6191)  time: 1.1716  data: 0.6428  max mem: 4087
# Epoch: [2]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.9413 (1.9664)  classification: 0.7698 (0.7756)  bbox_regression: 0.5651 (0.5737)  bbox_ctrness: 0.6072 (0.6171)  time: 1.1528  data: 0.6244  max mem: 4087
# Epoch: [2]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 1.9413 (1.9489)  classification: 0.7698 (0.7584)  bbox_regression: 0.5651 (0.5705)  bbox_ctrness: 0.6111 (0.6200)  time: 1.1273  data: 0.6001  max mem: 4087
# Epoch: [2]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 1.9321 (1.9160)  classification: 0.6909 (0.7291)  bbox_regression: 0.5579 (0.5671)  bbox_ctrness: 0.6111 (0.6197)  time: 1.1273  data: 0.6013  max mem: 4087
# Epoch: [2]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 1.9321 (1.9073)  classification: 0.7036 (0.7255)  bbox_regression: 0.5579 (0.5615)  bbox_ctrness: 0.6183 (0.6203)  time: 1.1251  data: 0.6000  max mem: 4087
# Epoch: [2]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 1.8789 (1.8936)  classification: 0.6909 (0.7090)  bbox_regression: 0.5579 (0.5634)  bbox_ctrness: 0.6183 (0.6212)  time: 1.0921  data: 0.5827  max mem: 4087
# Epoch: [2] Total time: 0:00:08 (1.0930 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:01  model_time: 0.4879 (0.4879)  evaluator_time: 0.0100 (0.0100)  time: 0.9090  data: 0.3721  max mem: 4087
# Test:  [1/2]  eta: 0:00:00  model_time: 0.3152 (0.4016)  evaluator_time: 0.0090 (0.0095)  time: 0.8017  data: 0.3581  max mem: 4087
# Test: Total time: 0:00:01 (0.8027 s / it)
# Averaged stats: model_time: 0.3152 (0.4016)  evaluator_time: 0.0090 (0.0095)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [3]  [0/8]  eta: 0:00:09  lr: 0.005500  loss: 1.7659 (1.7659)  classification: 0.6106 (0.6106)  bbox_regression: 0.5401 (0.5401)  bbox_ctrness: 0.6152 (0.6152)  time: 1.1841  data: 0.6671  max mem: 4087
# Epoch: [3]  [1/8]  eta: 0:00:07  lr: 0.005500  loss: 1.7659 (1.8004)  classification: 0.6106 (0.6429)  bbox_regression: 0.5401 (0.5467)  bbox_ctrness: 0.6064 (0.6108)  time: 1.1411  data: 0.6186  max mem: 4087
# Epoch: [3]  [2/8]  eta: 0:00:06  lr: 0.005500  loss: 1.7659 (1.7790)  classification: 0.6106 (0.6280)  bbox_regression: 0.5401 (0.5354)  bbox_ctrness: 0.6152 (0.6157)  time: 1.1484  data: 0.6241  max mem: 4087
# Epoch: [3]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.7362 (1.7593)  classification: 0.5981 (0.6005)  bbox_regression: 0.5401 (0.5424)  bbox_ctrness: 0.6152 (0.6164)  time: 1.1392  data: 0.6141  max mem: 4087
# Epoch: [3]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 1.7659 (1.7614)  classification: 0.5981 (0.5945)  bbox_regression: 0.5534 (0.5488)  bbox_ctrness: 0.6187 (0.6182)  time: 1.1619  data: 0.6353  max mem: 4087
# Epoch: [3]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 1.7362 (1.7280)  classification: 0.5705 (0.5656)  bbox_regression: 0.5401 (0.5448)  bbox_ctrness: 0.6152 (0.6176)  time: 1.1474  data: 0.6208  max mem: 4087
# Epoch: [3]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 1.7362 (1.7037)  classification: 0.5705 (0.5467)  bbox_regression: 0.5401 (0.5390)  bbox_ctrness: 0.6187 (0.6180)  time: 1.1338  data: 0.6076  max mem: 4087
# Epoch: [3]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 1.6999 (1.6932)  classification: 0.5180 (0.5344)  bbox_regression: 0.5401 (0.5397)  bbox_ctrness: 0.6187 (0.6191)  time: 1.0934  data: 0.5834  max mem: 4087
# Epoch: [3] Total time: 0:00:08 (1.0944 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:02  model_time: 0.6012 (0.6012)  evaluator_time: 0.1220 (0.1220)  time: 1.1333  data: 0.3711  max mem: 4087
# Test:  [1/2]  eta: 0:00:00  model_time: 0.3201 (0.4606)  evaluator_time: 0.0850 (0.1035)  time: 0.9537  data: 0.3561  max mem: 4087
# Test: Total time: 0:00:01 (0.9547 s / it)
# Averaged stats: model_time: 0.3201 (0.4606)  evaluator_time: 0.0850 (0.1035)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.113
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.111
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.111
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [4]  [0/8]  eta: 0:00:09  lr: 0.005500  loss: 1.5399 (1.5399)  classification: 0.4142 (0.4142)  bbox_regression: 0.5118 (0.5118)  bbox_ctrness: 0.6139 (0.6139)  time: 1.1339  data: 0.6101  max mem: 4087
# Epoch: [4]  [1/8]  eta: 0:00:08  lr: 0.005500  loss: 1.5214 (1.5306)  classification: 0.4142 (0.4166)  bbox_regression: 0.5047 (0.5083)  bbox_ctrness: 0.5977 (0.6058)  time: 1.1518  data: 0.6156  max mem: 4087
# Epoch: [4]  [2/8]  eta: 0:00:07  lr: 0.005500  loss: 1.5243 (1.5285)  classification: 0.4176 (0.4169)  bbox_regression: 0.5047 (0.5063)  bbox_ctrness: 0.6043 (0.6053)  time: 1.1697  data: 0.6361  max mem: 4087
# Epoch: [4]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.5243 (1.5337)  classification: 0.4142 (0.4088)  bbox_regression: 0.5047 (0.5152)  bbox_ctrness: 0.6043 (0.6096)  time: 1.1659  data: 0.6334  max mem: 4087
# Epoch: [4]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 1.5243 (1.5271)  classification: 0.4142 (0.4027)  bbox_regression: 0.5094 (0.5140)  bbox_ctrness: 0.6137 (0.6104)  time: 1.1566  data: 0.6251  max mem: 4087
# Epoch: [4]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 1.5214 (1.5258)  classification: 0.3967 (0.4017)  bbox_regression: 0.5094 (0.5133)  bbox_ctrness: 0.6130 (0.6109)  time: 1.1802  data: 0.6506  max mem: 4087
# Epoch: [4]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 1.5214 (1.5118)  classification: 0.3967 (0.3938)  bbox_regression: 0.5094 (0.5078)  bbox_ctrness: 0.6130 (0.6102)  time: 1.1613  data: 0.6339  max mem: 4087
# Epoch: [4]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 1.5191 (1.5057)  classification: 0.3846 (0.3882)  bbox_regression: 0.5047 (0.5066)  bbox_ctrness: 0.6130 (0.6110)  time: 1.1164  data: 0.6049  max mem: 4087
# Epoch: [4] Total time: 0:00:08 (1.1172 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:02  model_time: 0.4956 (0.4956)  evaluator_time: 0.1160 (0.1160)  time: 1.0197  data: 0.3781  max mem: 4087
# Test:  [1/2]  eta: 0:00:00  model_time: 0.3214 (0.4085)  evaluator_time: 0.0810 (0.0985)  time: 0.8946  data: 0.3586  max mem: 4087
# Test: Total time: 0:00:01 (0.8951 s / it)
# Averaged stats: model_time: 0.3214 (0.4085)  evaluator_time: 0.0810 (0.0985)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.041
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.196
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.041
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.018
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.064
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.128
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.128
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [5]  [0/8]  eta: 0:00:08  lr: 0.005500  loss: 1.5895 (1.5895)  classification: 0.4405 (0.4405)  bbox_regression: 0.5202 (0.5202)  bbox_ctrness: 0.6288 (0.6288)  time: 1.0665  data: 0.5411  max mem: 4087
# Epoch: [5]  [1/8]  eta: 0:00:07  lr: 0.005500  loss: 1.5136 (1.5515)  classification: 0.4018 (0.4211)  bbox_regression: 0.5029 (0.5116)  bbox_ctrness: 0.6089 (0.6189)  time: 1.1065  data: 0.5676  max mem: 4087
# Epoch: [5]  [2/8]  eta: 0:00:07  lr: 0.005500  loss: 1.5136 (1.5105)  classification: 0.4018 (0.3874)  bbox_regression: 0.5029 (0.5035)  bbox_ctrness: 0.6213 (0.6197)  time: 1.1711  data: 0.6348  max mem: 4087
# Epoch: [5]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.4388 (1.4926)  classification: 0.3261 (0.3721)  bbox_regression: 0.4953 (0.5014)  bbox_ctrness: 0.6174 (0.6191)  time: 1.1597  data: 0.6281  max mem: 4087
# Epoch: [5]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 1.4835 (1.4908)  classification: 0.3460 (0.3669)  bbox_regression: 0.5029 (0.5039)  bbox_ctrness: 0.6213 (0.6201)  time: 1.1655  data: 0.6339  max mem: 4087
# Epoch: [5]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 1.4388 (1.4804)  classification: 0.3261 (0.3588)  bbox_regression: 0.5029 (0.5045)  bbox_ctrness: 0.6174 (0.6170)  time: 1.1582  data: 0.6281  max mem: 4087
# Epoch: [5]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 1.4835 (1.4821)  classification: 0.3312 (0.3549)  bbox_regression: 0.5079 (0.5090)  bbox_ctrness: 0.6213 (0.6182)  time: 1.1540  data: 0.6246  max mem: 4087
# Epoch: [5]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 1.4835 (1.4865)  classification: 0.3312 (0.3558)  bbox_regression: 0.5079 (0.5139)  bbox_ctrness: 0.6174 (0.6167)  time: 1.1107  data: 0.5970  max mem: 4087
# Epoch: [5] Total time: 0:00:08 (1.1114 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:02  model_time: 0.5169 (0.5169)  evaluator_time: 0.1990 (0.1990)  time: 1.1160  data: 0.3691  max mem: 4087
# Test:  [1/2]  eta: 0:00:00  model_time: 0.3291 (0.4230)  evaluator_time: 0.1470 (0.1730)  time: 0.9796  data: 0.3546  max mem: 4087
# Test: Total time: 0:00:01 (0.9801 s / it)
# Averaged stats: model_time: 0.3291 (0.4230)  evaluator_time: 0.1470 (0.1730)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.117
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.117
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [6]  [0/8]  eta: 0:00:09  lr: 0.005500  loss: 1.4305 (1.4305)  classification: 0.3346 (0.3346)  bbox_regression: 0.4953 (0.4953)  bbox_ctrness: 0.6006 (0.6006)  time: 1.2098  data: 0.6792  max mem: 4087
# Epoch: [6]  [1/8]  eta: 0:00:08  lr: 0.005500  loss: 1.4080 (1.4192)  classification: 0.3103 (0.3225)  bbox_regression: 0.4953 (0.4953)  bbox_ctrness: 0.6006 (0.6014)  time: 1.2047  data: 0.6702  max mem: 4087
# Epoch: [6]  [2/8]  eta: 0:00:07  lr: 0.005500  loss: 1.4305 (1.4579)  classification: 0.3346 (0.3440)  bbox_regression: 0.4953 (0.5025)  bbox_ctrness: 0.6023 (0.6113)  time: 1.2214  data: 0.6798  max mem: 4087
# Epoch: [6]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.4279 (1.4504)  classification: 0.3346 (0.3419)  bbox_regression: 0.4953 (0.4963)  bbox_ctrness: 0.6023 (0.6122)  time: 1.1851  data: 0.6459  max mem: 4087
# Epoch: [6]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 1.4305 (1.4515)  classification: 0.3357 (0.3413)  bbox_regression: 0.4953 (0.4992)  bbox_ctrness: 0.6059 (0.6110)  time: 1.1878  data: 0.6491  max mem: 4087
# Epoch: [6]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 1.4305 (1.4483)  classification: 0.3346 (0.3356)  bbox_regression: 0.4953 (0.5004)  bbox_ctrness: 0.6059 (0.6123)  time: 1.1889  data: 0.6508  max mem: 4087
# Epoch: [6]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 1.4305 (1.4335)  classification: 0.3346 (0.3287)  bbox_regression: 0.4953 (0.4958)  bbox_ctrness: 0.6059 (0.6090)  time: 1.1697  data: 0.6321  max mem: 4087
# Epoch: [6]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 1.4279 (1.4276)  classification: 0.3103 (0.3250)  bbox_regression: 0.4953 (0.4917)  bbox_ctrness: 0.6059 (0.6109)  time: 1.1236  data: 0.6015  max mem: 4087
# Epoch: [6] Total time: 0:00:08 (1.1245 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:02  model_time: 0.5678 (0.5678)  evaluator_time: 0.1590 (0.1590)  time: 1.1679  data: 0.3881  max mem: 4087
# Test:  [1/2]  eta: 0:00:00  model_time: 0.3219 (0.4448)  evaluator_time: 0.1060 (0.1325)  time: 0.9850  data: 0.3676  max mem: 4087
# Test: Total time: 0:00:01 (0.9860 s / it)
# Averaged stats: model_time: 0.3219 (0.4448)  evaluator_time: 0.1060 (0.1325)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.064
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.254
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.064
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.025
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [7]  [0/8]  eta: 0:00:09  lr: 0.005500  loss: 1.3555 (1.3555)  classification: 0.3013 (0.3013)  bbox_regression: 0.4473 (0.4473)  bbox_ctrness: 0.6068 (0.6068)  time: 1.1791  data: 0.6441  max mem: 4087
# Epoch: [7]  [1/8]  eta: 0:00:07  lr: 0.005500  loss: 1.3555 (1.3891)  classification: 0.3013 (0.3153)  bbox_regression: 0.4473 (0.4707)  bbox_ctrness: 0.5995 (0.6032)  time: 1.1234  data: 0.6001  max mem: 4087
# Epoch: [7]  [2/8]  eta: 0:00:06  lr: 0.005500  loss: 1.3555 (1.3732)  classification: 0.3060 (0.3122)  bbox_regression: 0.4567 (0.4660)  bbox_ctrness: 0.5995 (0.5950)  time: 1.1204  data: 0.6135  max mem: 4087
# Epoch: [7]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.3555 (1.3730)  classification: 0.3013 (0.3076)  bbox_regression: 0.4567 (0.4697)  bbox_ctrness: 0.5980 (0.5957)  time: 1.1127  data: 0.6086  max mem: 4087
# Epoch: [7]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 1.3596 (1.3703)  classification: 0.3058 (0.3072)  bbox_regression: 0.4714 (0.4700)  bbox_ctrness: 0.5980 (0.5931)  time: 1.0954  data: 0.5981  max mem: 4087
# Epoch: [7]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 1.3555 (1.3650)  classification: 0.3013 (0.3016)  bbox_regression: 0.4567 (0.4668)  bbox_ctrness: 0.5980 (0.5966)  time: 1.0999  data: 0.6058  max mem: 4087
# Epoch: [7]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 1.3596 (1.3706)  classification: 0.3058 (0.3058)  bbox_regression: 0.4714 (0.4690)  bbox_ctrness: 0.5980 (0.5957)  time: 1.0994  data: 0.6074  max mem: 4087
# Epoch: [7]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 1.3596 (1.3745)  classification: 0.3013 (0.3020)  bbox_regression: 0.4714 (0.4739)  bbox_ctrness: 0.5980 (0.5985)  time: 1.0600  data: 0.5848  max mem: 4087
# Epoch: [7] Total time: 0:00:08 (1.0605 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:02  model_time: 0.5521 (0.5521)  evaluator_time: 0.1210 (0.1210)  time: 1.0913  data: 0.3821  max mem: 4087
# Test:  [1/2]  eta: 0:00:00  model_time: 0.2841 (0.4181)  evaluator_time: 0.0780 (0.0995)  time: 0.9097  data: 0.3611  max mem: 4087
# Test: Total time: 0:00:01 (0.9102 s / it)
# Averaged stats: model_time: 0.2841 (0.4181)  evaluator_time: 0.0780 (0.0995)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.263
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.025
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.114
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.159
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.159
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [8]  [0/8]  eta: 0:00:08  lr: 0.005500  loss: 1.4213 (1.4213)  classification: 0.3194 (0.3194)  bbox_regression: 0.4730 (0.4730)  bbox_ctrness: 0.6289 (0.6289)  time: 1.0906  data: 0.6201  max mem: 4087
# Epoch: [8]  [1/8]  eta: 0:00:07  lr: 0.005500  loss: 1.3258 (1.3735)  classification: 0.2513 (0.2854)  bbox_regression: 0.4615 (0.4672)  bbox_ctrness: 0.6130 (0.6210)  time: 1.0909  data: 0.6251  max mem: 4087
# Epoch: [8]  [2/8]  eta: 0:00:06  lr: 0.005500  loss: 1.3408 (1.3626)  classification: 0.2912 (0.2873)  bbox_regression: 0.4615 (0.4553)  bbox_ctrness: 0.6181 (0.6200)  time: 1.0690  data: 0.6031  max mem: 4087
# Epoch: [8]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.3374 (1.3563)  classification: 0.2702 (0.2830)  bbox_regression: 0.4518 (0.4545)  bbox_ctrness: 0.6154 (0.6188)  time: 1.0773  data: 0.6121  max mem: 4087
# Epoch: [8]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 1.3408 (1.3660)  classification: 0.2824 (0.2829)  bbox_regression: 0.4615 (0.4680)  bbox_ctrness: 0.6154 (0.6152)  time: 1.0619  data: 0.5969  max mem: 4087
# Epoch: [8]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 1.3408 (1.3708)  classification: 0.2824 (0.2854)  bbox_regression: 0.4615 (0.4712)  bbox_ctrness: 0.6130 (0.6142)  time: 1.0648  data: 0.5996  max mem: 4087
# Epoch: [8]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 1.3408 (1.3665)  classification: 0.2824 (0.2831)  bbox_regression: 0.4615 (0.4681)  bbox_ctrness: 0.6154 (0.6153)  time: 1.0549  data: 0.5907  max mem: 4087
# Epoch: [8]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 1.3408 (1.3712)  classification: 0.2824 (0.2902)  bbox_regression: 0.4615 (0.4678)  bbox_ctrness: 0.6130 (0.6133)  time: 1.0259  data: 0.5756  max mem: 4087
# Epoch: [8] Total time: 0:00:08 (1.0267 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:02  model_time: 0.4811 (0.4811)  evaluator_time: 0.1800 (0.1800)  time: 1.0622  data: 0.3711  max mem: 4087
# Test:  [1/2]  eta: 0:00:00  model_time: 0.2851 (0.3831)  evaluator_time: 0.1260 (0.1530)  time: 0.9212  data: 0.3566  max mem: 4087
# Test: Total time: 0:00:01 (0.9222 s / it)
# Averaged stats: model_time: 0.2851 (0.3831)  evaluator_time: 0.1260 (0.1530)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.265
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [9]  [0/8]  eta: 0:00:08  lr: 0.005500  loss: 1.3533 (1.3533)  classification: 0.2869 (0.2869)  bbox_regression: 0.4758 (0.4758)  bbox_ctrness: 0.5906 (0.5906)  time: 1.0922  data: 0.6221  max mem: 4087
# Epoch: [9]  [1/8]  eta: 0:00:07  lr: 0.005500  loss: 1.3152 (1.3343)  classification: 0.2662 (0.2766)  bbox_regression: 0.4432 (0.4595)  bbox_ctrness: 0.5906 (0.5982)  time: 1.0847  data: 0.6081  max mem: 4087
# Epoch: [9]  [2/8]  eta: 0:00:06  lr: 0.005500  loss: 1.3396 (1.3360)  classification: 0.2766 (0.2766)  bbox_regression: 0.4666 (0.4619)  bbox_ctrness: 0.5964 (0.5976)  time: 1.0796  data: 0.6075  max mem: 4087
# Epoch: [9]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.3396 (1.3476)  classification: 0.2740 (0.2759)  bbox_regression: 0.4666 (0.4672)  bbox_ctrness: 0.5964 (0.6044)  time: 1.0625  data: 0.5924  max mem: 4087
# Epoch: [9]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 1.3396 (1.3432)  classification: 0.2766 (0.2786)  bbox_regression: 0.4666 (0.4629)  bbox_ctrness: 0.5964 (0.6016)  time: 1.0594  data: 0.5895  max mem: 4087
# Epoch: [9]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 1.3396 (1.3478)  classification: 0.2766 (0.2808)  bbox_regression: 0.4666 (0.4668)  bbox_ctrness: 0.5927 (0.6001)  time: 1.0671  data: 0.5980  max mem: 4087
# Epoch: [9]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 1.3454 (1.3474)  classification: 0.2796 (0.2806)  bbox_regression: 0.4758 (0.4681)  bbox_ctrness: 0.5927 (0.5987)  time: 1.0700  data: 0.6013  max mem: 4087
# Epoch: [9]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 1.3454 (1.3489)  classification: 0.2766 (0.2792)  bbox_regression: 0.4758 (0.4718)  bbox_ctrness: 0.5927 (0.5979)  time: 1.0386  data: 0.5850  max mem: 4087
# Epoch: [9] Total time: 0:00:08 (1.0395 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:02  model_time: 0.5431 (0.5431)  evaluator_time: 0.1390 (0.1390)  time: 1.1503  data: 0.4351  max mem: 4087
# Test:  [1/2]  eta: 0:00:00  model_time: 0.2851 (0.4141)  evaluator_time: 0.0890 (0.1140)  time: 0.9442  data: 0.3856  max mem: 4087
# Test: Total time: 0:00:01 (0.9452 s / it)
# Averaged stats: model_time: 0.2851 (0.4141)  evaluator_time: 0.0890 (0.1140)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.277
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.029
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.112
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.158
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.158
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [10]  [0/8]  eta: 0:00:08  lr: 0.005500  loss: 1.3950 (1.3950)  classification: 0.2891 (0.2891)  bbox_regression: 0.4818 (0.4818)  bbox_ctrness: 0.6240 (0.6240)  time: 1.0202  data: 0.5531  max mem: 4087
# Epoch: [10]  [1/8]  eta: 0:00:07  lr: 0.005500  loss: 1.3763 (1.3856)  classification: 0.2891 (0.3052)  bbox_regression: 0.4598 (0.4708)  bbox_ctrness: 0.5952 (0.6096)  time: 1.0311  data: 0.5655  max mem: 4087
# Epoch: [10]  [2/8]  eta: 0:00:06  lr: 0.005500  loss: 1.3763 (1.3608)  classification: 0.2891 (0.2923)  bbox_regression: 0.4598 (0.4652)  bbox_ctrness: 0.5952 (0.6033)  time: 1.0648  data: 0.6007  max mem: 4087
# Epoch: [10]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.3155 (1.3494)  classification: 0.2663 (0.2851)  bbox_regression: 0.4540 (0.4592)  bbox_ctrness: 0.5952 (0.6051)  time: 1.0842  data: 0.6196  max mem: 4087
# Epoch: [10]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 1.3155 (1.3383)  classification: 0.2663 (0.2767)  bbox_regression: 0.4540 (0.4553)  bbox_ctrness: 0.6106 (0.6063)  time: 1.0668  data: 0.6019  max mem: 4087
# Epoch: [10]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 1.3110 (1.3295)  classification: 0.2636 (0.2739)  bbox_regression: 0.4413 (0.4510)  bbox_ctrness: 0.5960 (0.6046)  time: 1.0659  data: 0.6021  max mem: 4087
# Epoch: [10]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 1.3155 (1.3284)  classification: 0.2663 (0.2728)  bbox_regression: 0.4540 (0.4522)  bbox_ctrness: 0.5961 (0.6034)  time: 1.0596  data: 0.5945  max mem: 4087
# Epoch: [10]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 1.3155 (1.3449)  classification: 0.2663 (0.2785)  bbox_regression: 0.4540 (0.4593)  bbox_ctrness: 0.5961 (0.6071)  time: 1.0280  data: 0.5771  max mem: 4087
# Epoch: [10] Total time: 0:00:08 (1.0287 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:02  model_time: 0.5721 (0.5721)  evaluator_time: 0.1290 (0.1290)  time: 1.0803  data: 0.3501  max mem: 4087
# Test:  [1/2]  eta: 0:00:00  model_time: 0.2861 (0.4291)  evaluator_time: 0.0760 (0.1025)  time: 0.9032  data: 0.3441  max mem: 4087
# Test: Total time: 0:00:01 (0.9037 s / it)
# Averaged stats: model_time: 0.2861 (0.4291)  evaluator_time: 0.0760 (0.1025)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.278
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.030
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.122
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.162
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.162
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [11]  [0/8]  eta: 0:00:09  lr: 0.005500  loss: 1.3427 (1.3427)  classification: 0.2936 (0.2936)  bbox_regression: 0.4528 (0.4528)  bbox_ctrness: 0.5963 (0.5963)  time: 1.1403  data: 0.6732  max mem: 4087
# Epoch: [11]  [1/8]  eta: 0:00:08  lr: 0.005500  loss: 1.3295 (1.3361)  classification: 0.2739 (0.2837)  bbox_regression: 0.4528 (0.4569)  bbox_ctrness: 0.5946 (0.5955)  time: 1.1493  data: 0.6837  max mem: 4087
# Epoch: [11]  [2/8]  eta: 0:00:06  lr: 0.005500  loss: 1.3426 (1.3383)  classification: 0.2874 (0.2850)  bbox_regression: 0.4528 (0.4520)  bbox_ctrness: 0.5963 (0.6013)  time: 1.1106  data: 0.6455  max mem: 4087
# Epoch: [11]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.3295 (1.3262)  classification: 0.2739 (0.2762)  bbox_regression: 0.4528 (0.4535)  bbox_ctrness: 0.5946 (0.5965)  time: 1.1131  data: 0.6441  max mem: 4087
# Epoch: [11]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 1.3295 (1.3095)  classification: 0.2739 (0.2715)  bbox_regression: 0.4528 (0.4436)  bbox_ctrness: 0.5946 (0.5944)  time: 1.1150  data: 0.6303  max mem: 4087
# Epoch: [11]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 1.2900 (1.3037)  classification: 0.2548 (0.2687)  bbox_regression: 0.4422 (0.4411)  bbox_ctrness: 0.5911 (0.5939)  time: 1.1126  data: 0.6233  max mem: 4087
# Epoch: [11]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 1.3295 (1.3128)  classification: 0.2739 (0.2742)  bbox_regression: 0.4504 (0.4424)  bbox_ctrness: 0.5946 (0.5961)  time: 1.1144  data: 0.6220  max mem: 4087
# Epoch: [11]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 1.3295 (1.3157)  classification: 0.2548 (0.2715)  bbox_regression: 0.4504 (0.4445)  bbox_ctrness: 0.5946 (0.5997)  time: 1.0925  data: 0.6145  max mem: 4087
# Epoch: [11] Total time: 0:00:08 (1.0931 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:02  model_time: 0.5416 (0.5416)  evaluator_time: 0.1320 (0.1320)  time: 1.0738  data: 0.3701  max mem: 4087
# Test:  [1/2]  eta: 0:00:00  model_time: 0.2841 (0.4128)  evaluator_time: 0.0820 (0.1070)  time: 0.9060  data: 0.3576  max mem: 4087
# Test: Total time: 0:00:01 (0.9065 s / it)
# Averaged stats: model_time: 0.2841 (0.4128)  evaluator_time: 0.0820 (0.1070)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.338
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.181
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.181
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [12]  [0/8]  eta: 0:00:08  lr: 0.005500  loss: 1.3133 (1.3133)  classification: 0.2720 (0.2720)  bbox_regression: 0.4661 (0.4661)  bbox_ctrness: 0.5751 (0.5751)  time: 1.1237  data: 0.6071  max mem: 4087
# Epoch: [12]  [1/8]  eta: 0:00:07  lr: 0.005500  loss: 1.2897 (1.3015)  classification: 0.2372 (0.2546)  bbox_regression: 0.4494 (0.4577)  bbox_ctrness: 0.5751 (0.5891)  time: 1.1123  data: 0.6001  max mem: 4087
# Epoch: [12]  [2/8]  eta: 0:00:06  lr: 0.005500  loss: 1.3133 (1.3178)  classification: 0.2686 (0.2593)  bbox_regression: 0.4661 (0.4648)  bbox_ctrness: 0.6029 (0.5937)  time: 1.1363  data: 0.6208  max mem: 4087
# Epoch: [12]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.2897 (1.3054)  classification: 0.2528 (0.2577)  bbox_regression: 0.4494 (0.4564)  bbox_ctrness: 0.5844 (0.5914)  time: 1.1436  data: 0.6281  max mem: 4087
# Epoch: [12]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 1.3133 (1.3145)  classification: 0.2686 (0.2636)  bbox_regression: 0.4658 (0.4582)  bbox_ctrness: 0.5978 (0.5927)  time: 1.1343  data: 0.6195  max mem: 4087
# Epoch: [12]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 1.2897 (1.3042)  classification: 0.2528 (0.2593)  bbox_regression: 0.4494 (0.4494)  bbox_ctrness: 0.5978 (0.5955)  time: 1.1204  data: 0.6081  max mem: 4087
# Epoch: [12]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 1.3133 (1.3086)  classification: 0.2672 (0.2605)  bbox_regression: 0.4564 (0.4504)  bbox_ctrness: 0.6029 (0.5978)  time: 1.1190  data: 0.6065  max mem: 4087
# Epoch: [12]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 1.3133 (1.3155)  classification: 0.2672 (0.2659)  bbox_regression: 0.4494 (0.4496)  bbox_ctrness: 0.6029 (0.6000)  time: 1.0776  data: 0.5840  max mem: 4087
# Epoch: [12] Total time: 0:00:08 (1.0784 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:02  model_time: 0.5732 (0.5732)  evaluator_time: 0.1310 (0.1310)  time: 1.1173  data: 0.3801  max mem: 4087
# Test:  [1/2]  eta: 0:00:00  model_time: 0.2841 (0.4286)  evaluator_time: 0.0780 (0.1045)  time: 0.9307  data: 0.3666  max mem: 4087
# Test: Total time: 0:00:01 (0.9312 s / it)
# Averaged stats: model_time: 0.2841 (0.4286)  evaluator_time: 0.0780 (0.1045)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.082
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.296
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.082
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.026
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.127
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.177
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.177
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [13]  [0/8]  eta: 0:00:08  lr: 0.005500  loss: 1.3552 (1.3552)  classification: 0.3086 (0.3086)  bbox_regression: 0.4452 (0.4452)  bbox_ctrness: 0.6014 (0.6014)  time: 1.0600  data: 0.5431  max mem: 4087
# Epoch: [13]  [1/8]  eta: 0:00:07  lr: 0.005500  loss: 1.3078 (1.3315)  classification: 0.2614 (0.2850)  bbox_regression: 0.4452 (0.4497)  bbox_ctrness: 0.5921 (0.5968)  time: 1.0623  data: 0.5526  max mem: 4087
# Epoch: [13]  [2/8]  eta: 0:00:06  lr: 0.005500  loss: 1.3078 (1.3159)  classification: 0.2614 (0.2738)  bbox_regression: 0.4489 (0.4494)  bbox_ctrness: 0.5921 (0.5926)  time: 1.0784  data: 0.5661  max mem: 4087
# Epoch: [13]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.2848 (1.3076)  classification: 0.2603 (0.2705)  bbox_regression: 0.4452 (0.4484)  bbox_ctrness: 0.5843 (0.5888)  time: 1.0764  data: 0.5649  max mem: 4087
# Epoch: [13]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 1.3045 (1.3070)  classification: 0.2603 (0.2637)  bbox_regression: 0.4489 (0.4514)  bbox_ctrness: 0.5921 (0.5919)  time: 1.0641  data: 0.5539  max mem: 4087
# Epoch: [13]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 1.2848 (1.2971)  classification: 0.2516 (0.2586)  bbox_regression: 0.4452 (0.4468)  bbox_ctrness: 0.5910 (0.5917)  time: 1.0895  data: 0.5760  max mem: 4087
# Epoch: [13]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 1.3045 (1.2997)  classification: 0.2516 (0.2563)  bbox_regression: 0.4489 (0.4495)  bbox_ctrness: 0.5921 (0.5938)  time: 1.1045  data: 0.5898  max mem: 4087
# Epoch: [13]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 1.3020 (1.3000)  classification: 0.2516 (0.2575)  bbox_regression: 0.4481 (0.4493)  bbox_ctrness: 0.5910 (0.5932)  time: 1.0826  data: 0.5853  max mem: 4087
# Epoch: [13] Total time: 0:00:08 (1.0835 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:02  model_time: 0.5506 (0.5506)  evaluator_time: 0.1270 (0.1270)  time: 1.0858  data: 0.3791  max mem: 4087
# Test:  [1/2]  eta: 0:00:00  model_time: 0.2841 (0.4174)  evaluator_time: 0.0780 (0.1025)  time: 0.9130  data: 0.3646  max mem: 4087
# Test: Total time: 0:00:01 (0.9140 s / it)
# Averaged stats: model_time: 0.2841 (0.4174)  evaluator_time: 0.0780 (0.1025)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.307
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.030
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.177
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.177
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [14]  [0/8]  eta: 0:00:08  lr: 0.005500  loss: 1.2634 (1.2634)  classification: 0.2391 (0.2391)  bbox_regression: 0.4263 (0.4263)  bbox_ctrness: 0.5981 (0.5981)  time: 1.0512  data: 0.5421  max mem: 4087
# Epoch: [14]  [1/8]  eta: 0:00:07  lr: 0.005500  loss: 1.2634 (1.2936)  classification: 0.2391 (0.2540)  bbox_regression: 0.4263 (0.4508)  bbox_ctrness: 0.5796 (0.5888)  time: 1.0738  data: 0.5649  max mem: 4087
# Epoch: [14]  [2/8]  eta: 0:00:06  lr: 0.005500  loss: 1.2634 (1.2815)  classification: 0.2577 (0.2552)  bbox_regression: 0.4263 (0.4376)  bbox_ctrness: 0.5883 (0.5886)  time: 1.0726  data: 0.5639  max mem: 4087
# Epoch: [14]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.2597 (1.2760)  classification: 0.2391 (0.2493)  bbox_regression: 0.4168 (0.4324)  bbox_ctrness: 0.5883 (0.5943)  time: 1.0908  data: 0.5793  max mem: 4087
# Epoch: [14]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 1.2597 (1.2585)  classification: 0.2391 (0.2444)  bbox_regression: 0.4168 (0.4262)  bbox_ctrness: 0.5883 (0.5879)  time: 1.1258  data: 0.6103  max mem: 4087
# Epoch: [14]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 1.2597 (1.2614)  classification: 0.2391 (0.2482)  bbox_regression: 0.4168 (0.4262)  bbox_ctrness: 0.5822 (0.5870)  time: 1.1176  data: 0.6036  max mem: 4087
# Epoch: [14]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 1.2634 (1.2639)  classification: 0.2391 (0.2469)  bbox_regression: 0.4263 (0.4284)  bbox_ctrness: 0.5883 (0.5886)  time: 1.1059  data: 0.5937  max mem: 4087
# Epoch: [14]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 1.2634 (1.2700)  classification: 0.2391 (0.2487)  bbox_regression: 0.4263 (0.4305)  bbox_ctrness: 0.5883 (0.5908)  time: 1.0707  data: 0.5767  max mem: 4087
# Epoch: [14] Total time: 0:00:08 (1.0717 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:02  model_time: 0.6068 (0.6068)  evaluator_time: 0.1190 (0.1190)  time: 1.1309  data: 0.3731  max mem: 4087
# Test:  [1/2]  eta: 0:00:00  model_time: 0.2871 (0.4469)  evaluator_time: 0.0720 (0.0955)  time: 0.9315  data: 0.3596  max mem: 4087
# Test: Total time: 0:00:01 (0.9325 s / it)
# Averaged stats: model_time: 0.2871 (0.4469)  evaluator_time: 0.0720 (0.0955)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.400
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.201
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.201
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [15]  [0/8]  eta: 0:00:08  lr: 0.005500  loss: 1.2908 (1.2908)  classification: 0.2515 (0.2515)  bbox_regression: 0.4425 (0.4425)  bbox_ctrness: 0.5968 (0.5968)  time: 1.0911  data: 0.5791  max mem: 4087
# ...
# Epoch: [20]  [0/8]  eta: 0:00:08  lr: 0.005500  loss: 1.2221 (1.2221)  classification: 0.2425 (0.2425)  bbox_regression: 0.4097 (0.4097)  bbox_ctrness: 0.5699 (0.5699)  time: 1.0917  data: 0.5781  max mem: 4087
# Epoch: [20]  [1/8]  eta: 0:00:07  lr: 0.005500  loss: 1.2221 (1.2629)  classification: 0.2425 (0.2560)  bbox_regression: 0.4044 (0.4071)  bbox_ctrness: 0.5699 (0.5999)  time: 1.1342  data: 0.6176  max mem: 4087
# Epoch: [20]  [2/8]  eta: 0:00:06  lr: 0.005500  loss: 1.2594 (1.2618)  classification: 0.2695 (0.2668)  bbox_regression: 0.4044 (0.4038)  bbox_ctrness: 0.5737 (0.5912)  time: 1.1249  data: 0.6065  max mem: 4087
# Epoch: [20]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.2594 (1.2754)  classification: 0.2695 (0.2764)  bbox_regression: 0.4039 (0.4038)  bbox_ctrness: 0.5737 (0.5952)  time: 1.1133  data: 0.5972  max mem: 4087
# Epoch: [20]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 1.2627 (1.2729)  classification: 0.2695 (0.2700)  bbox_regression: 0.4044 (0.4086)  bbox_ctrness: 0.5903 (0.5942)  time: 1.1433  data: 0.6196  max mem: 4087
# Epoch: [20]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 1.2594 (1.2697)  classification: 0.2443 (0.2643)  bbox_regression: 0.4044 (0.4125)  bbox_ctrness: 0.5860 (0.5929)  time: 1.1165  data: 0.5975  max mem: 4087
# Epoch: [20]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 1.2627 (1.2786)  classification: 0.2695 (0.2677)  bbox_regression: 0.4097 (0.4170)  bbox_ctrness: 0.5903 (0.5940)  time: 1.1076  data: 0.5910  max mem: 4087
# Epoch: [20]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 1.2627 (1.2780)  classification: 0.2616 (0.2669)  bbox_regression: 0.4097 (0.4174)  bbox_ctrness: 0.5903 (0.5937)  time: 1.0720  data: 0.5742  max mem: 4087
# Epoch: [20] Total time: 0:00:08 (1.0726 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:02  model_time: 0.5722 (0.5722)  evaluator_time: 0.0650 (0.0650)  time: 1.0243  data: 0.3541  max mem: 4087
# Test:  [1/2]  eta: 0:00:00  model_time: 0.2841 (0.4281)  evaluator_time: 0.0440 (0.0545)  time: 0.8627  data: 0.3496  max mem: 4087
# Test: Total time: 0:00:01 (0.8632 s / it)
# Averaged stats: model_time: 0.2841 (0.4281)  evaluator_time: 0.0440 (0.0545)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.309
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.139
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [21]  [0/8]  eta: 0:00:08  lr: 0.005500  loss: 1.3134 (1.3134)  classification: 0.2922 (0.2922)  bbox_regression: 0.4309 (0.4309)  bbox_ctrness: 0.5903 (0.5903)  time: 1.0579  data: 0.5501  max mem: 4087
# Epoch: [21]  [1/8]  eta: 0:00:07  lr: 0.005500  loss: 1.2783 (1.2959)  classification: 0.2563 (0.2743)  bbox_regression: 0.4309 (0.4336)  bbox_ctrness: 0.5856 (0.5880)  time: 1.0786  data: 0.5696  max mem: 4087
# Epoch: [21]  [2/8]  eta: 0:00:06  lr: 0.005500  loss: 1.2783 (1.2816)  classification: 0.2563 (0.2624)  bbox_regression: 0.4309 (0.4276)  bbox_ctrness: 0.5903 (0.5916)  time: 1.0776  data: 0.5691  max mem: 4087
# Epoch: [21]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.2529 (1.2603)  classification: 0.2386 (0.2508)  bbox_regression: 0.4155 (0.4241)  bbox_ctrness: 0.5856 (0.5854)  time: 1.0849  data: 0.5724  max mem: 4087
# Epoch: [21]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 1.2529 (1.2587)  classification: 0.2498 (0.2506)  bbox_regression: 0.4159 (0.4225)  bbox_ctrness: 0.5867 (0.5856)  time: 1.0945  data: 0.5831  max mem: 4087
# Epoch: [21]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 1.2525 (1.2554)  classification: 0.2498 (0.2506)  bbox_regression: 0.4159 (0.4225)  bbox_ctrness: 0.5856 (0.5824)  time: 1.1173  data: 0.6020  max mem: 4087
# Epoch: [21]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 1.2529 (1.2571)  classification: 0.2498 (0.2497)  bbox_regression: 0.4159 (0.4212)  bbox_ctrness: 0.5867 (0.5862)  time: 1.1187  data: 0.6033  max mem: 4087
# Epoch: [21]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 1.2529 (1.2621)  classification: 0.2498 (0.2511)  bbox_regression: 0.4159 (0.4249)  bbox_ctrness: 0.5859 (0.5862)  time: 1.0823  data: 0.5848  max mem: 4087
# Epoch: [21] Total time: 0:00:08 (1.0832 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:01  model_time: 0.4692 (0.4692)  evaluator_time: 0.0890 (0.0890)  time: 0.9484  data: 0.3601  max mem: 4087
# Test:  [1/2]  eta: 0:00:00  model_time: 0.2861 (0.3777)  evaluator_time: 0.0580 (0.0735)  time: 0.8313  data: 0.3516  max mem: 4087
# Test: Total time: 0:00:01 (0.8323 s / it)
# Averaged stats: model_time: 0.2861 (0.3777)  evaluator_time: 0.0580 (0.0735)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.250
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.109
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.142
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.142
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [22]  [0/8]  eta: 0:00:08  lr: 0.005500  loss: 1.2812 (1.2812)  classification: 0.2456 (0.2456)  bbox_regression: 0.4462 (0.4462)  bbox_ctrness: 0.5894 (0.5894)  time: 1.0909  data: 0.5751  max mem: 4087
# Epoch: [22]  [1/8]  eta: 0:00:08  lr: 0.005500  loss: 1.2110 (1.2461)  classification: 0.2149 (0.2302)  bbox_regression: 0.4381 (0.4422)  bbox_ctrness: 0.5580 (0.5737)  time: 1.1429  data: 0.6236  max mem: 4087
# Epoch: [22]  [2/8]  eta: 0:00:06  lr: 0.005500  loss: 1.2317 (1.2413)  classification: 0.2209 (0.2271)  bbox_regression: 0.4381 (0.4312)  bbox_ctrness: 0.5894 (0.5830)  time: 1.1307  data: 0.6138  max mem: 4087
# Epoch: [22]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.2110 (1.2269)  classification: 0.2177 (0.2248)  bbox_regression: 0.4093 (0.4210)  bbox_ctrness: 0.5759 (0.5812)  time: 1.1204  data: 0.6049  max mem: 4087
# Epoch: [22]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 1.2317 (1.2343)  classification: 0.2209 (0.2286)  bbox_regression: 0.4317 (0.4231)  bbox_ctrness: 0.5882 (0.5826)  time: 1.1210  data: 0.6021  max mem: 4087
# Epoch: [22]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 1.2317 (1.2346)  classification: 0.2209 (0.2314)  bbox_regression: 0.4165 (0.4220)  bbox_ctrness: 0.5759 (0.5812)  time: 1.1341  data: 0.6140  max mem: 4087
# Epoch: [22]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 1.2317 (1.2333)  classification: 0.2424 (0.2330)  bbox_regression: 0.4165 (0.4207)  bbox_ctrness: 0.5759 (0.5796)  time: 1.1290  data: 0.6104  max mem: 4087
# Epoch: [22]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 1.2317 (1.2348)  classification: 0.2224 (0.2316)  bbox_regression: 0.4165 (0.4204)  bbox_ctrness: 0.5759 (0.5828)  time: 1.0896  data: 0.5904  max mem: 4087
# Epoch: [22] Total time: 0:00:08 (1.0906 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:02  model_time: 0.5331 (0.5331)  evaluator_time: 0.1170 (0.1170)  time: 1.0483  data: 0.3691  max mem: 4087
# Test:  [1/2]  eta: 0:00:00  model_time: 0.2881 (0.4106)  evaluator_time: 0.0810 (0.0990)  time: 0.8947  data: 0.3571  max mem: 4087
# Test: Total time: 0:00:01 (0.8957 s / it)
# Averaged stats: model_time: 0.2881 (0.4106)  evaluator_time: 0.0810 (0.0990)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.223
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.026
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.103
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.142
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.142
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [23]  [0/8]  eta: 0:00:09  lr: 0.005500  loss: 1.2707 (1.2707)  classification: 0.2368 (0.2368)  bbox_regression: 0.4513 (0.4513)  bbox_ctrness: 0.5827 (0.5827)  time: 1.1818  data: 0.6521  max mem: 4087
# Epoch: [23]  [1/8]  eta: 0:00:07  lr: 0.005500  loss: 1.2108 (1.2408)  classification: 0.2261 (0.2315)  bbox_regression: 0.4129 (0.4321)  bbox_ctrness: 0.5718 (0.5773)  time: 1.1185  data: 0.6031  max mem: 4087
# Epoch: [23]  [2/8]  eta: 0:00:06  lr: 0.005500  loss: 1.2108 (1.2264)  classification: 0.2261 (0.2276)  bbox_regression: 0.4129 (0.4233)  bbox_ctrness: 0.5720 (0.5755)  time: 1.1391  data: 0.6225  max mem: 4087
# Epoch: [23]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.2108 (1.2340)  classification: 0.2200 (0.2208)  bbox_regression: 0.4129 (0.4298)  bbox_ctrness: 0.5720 (0.5834)  time: 1.1590  data: 0.6394  max mem: 4087
# Epoch: [23]  [4/8]  eta: 0:00:04  lr: 0.005500  loss: 1.2159 (1.2304)  classification: 0.2200 (0.2183)  bbox_regression: 0.4290 (0.4296)  bbox_ctrness: 0.5785 (0.5824)  time: 1.1433  data: 0.6263  max mem: 4087
# Epoch: [23]  [5/8]  eta: 0:00:03  lr: 0.005500  loss: 1.2108 (1.2255)  classification: 0.2084 (0.2148)  bbox_regression: 0.4219 (0.4283)  bbox_ctrness: 0.5785 (0.5824)  time: 1.1325  data: 0.6215  max mem: 4087
# Epoch: [23]  [6/8]  eta: 0:00:02  lr: 0.005500  loss: 1.2159 (1.2274)  classification: 0.2131 (0.2145)  bbox_regression: 0.4290 (0.4289)  bbox_ctrness: 0.5820 (0.5840)  time: 1.1536  data: 0.6486  max mem: 4087
# Epoch: [23]  [7/8]  eta: 0:00:01  lr: 0.005500  loss: 1.2159 (1.2282)  classification: 0.2084 (0.2121)  bbox_regression: 0.4290 (0.4309)  bbox_ctrness: 0.5820 (0.5852)  time: 1.1042  data: 0.6178  max mem: 4087
# Epoch: [23] Total time: 0:00:08 (1.1051 s / it)
# creating index...
# index created!
# Test:  [0/2]  eta: 0:00:02  model_time: 0.5161 (0.5161)  evaluator_time: 0.1000 (0.1000)  time: 1.0322  data: 0.3861  max mem: 4087
# Test:  [1/2]  eta: 0:00:00  model_time: 0.2851 (0.4006)  evaluator_time: 0.0620 (0.0810)  time: 0.8747  data: 0.3646  max mem: 4087
# Test: Total time: 0:00:01 (0.8757 s / it)
# Averaged stats: model_time: 0.2851 (0.4006)  evaluator_time: 0.0620 (0.0810)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.361
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.030
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.147
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [24]  [0/8]  eta: 0:00:08  lr: 0.005500  loss: 1.2539 (1.2539)  classification: 0.2482 (0.2482)  bbox_regression: 0.4215 (0.4215)  bbox_ctrness: 0.5843 (0.5843)  time: 1.0952  data: 0.6331  max mem: 4087
# Epoch: [24]  [1/8]  eta: 0:00:07  lr: 0.005500  loss: 1.2514 (1.2527)  classification: 0.2183 (0.2333)  bbox_regression: 0.4215 (0.4249)  bbox_ctrness: 0.5843 (0.5945)  time: 1.0652  data: 0.6036  max mem: 4087
# Epoch: [24]  [2/8]  eta: 0:00:06  lr: 0.005500  loss: 1.2514 (1.2381)  classification: 0.2200 (0.2289)  bbox_regression: 0.4215 (0.4225)  bbox_ctrness: 0.5843 (0.5868)  time: 1.0764  data: 0.6125  max mem: 4087
# Epoch: [24]  [3/8]  eta: 0:00:05  lr: 0.005500  loss: 1.2090 (1.2299)  classification: 0.2183 (0.2219)  bbox_regression: 0.4192 (0.4217)  bbox_ctrness: 0.5843 (0.5863)  time: 1.0839  data: 0.5981  max mem: 4087
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12868\325150663.py in <module>
#       3 for epoch in range(num_epochs):
#       4     #training at each epoch
# ----> 5     train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=1)
#       6     #update lr
#       7     lr_scheduler.step()
#
# d:\Abdallah\Venvs\tvenv\notebook\engine.py in train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq)
#      28         targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
#      29
# ---> 30         loss_dict = model(images, targets)
#      31
#      32         losses = sum(loss for loss in loss_dict.values())
#
# d:\Abdallah\Venvs\tvenv\torch\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# d:\Abdallah\Venvs\tvenv\torch\lib\site-packages\torchvision\models\detection\fcos.py in forward(self, images, targets)
#     629             else:
#     630                 # compute the losses
# --> 631                 losses = self.compute_loss(targets, head_outputs, anchors, num_anchors_per_level)
#     632         else:
#     633             # split outputs per level
#
# d:\Abdallah\Venvs\tvenv\torch\lib\site-packages\torchvision\models\detection\fcos.py in compute_loss(self, targets, head_outputs, anchors, num_anchors_per_level)
#     481             matched_idxs.append(matched_idx)
#     482
# --> 483         return self.head.compute_loss(targets, head_outputs, anchors, matched_idxs)
#     484
#     485     def postprocess_detections(
#
# d:\Abdallah\Venvs\tvenv\torch\lib\site-packages\torchvision\models\detection\fcos.py in compute_loss(self, targets, head_outputs, anchors, matched_idxs)
#      84         # compute foregroud
#      85         foregroud_mask = all_gt_classes_targets >= 0
# ---> 86         num_foreground = foregroud_mask.sum().item()
#      87
#      88         # classification loss
#
# KeyboardInterrupt:

# %%
#original prediction and iou threshold
def apply_nms(orig_prediction, iou_thresh = 0.3):
    #torchvis returns the indices of the bboxes to keep
    keep = torchvision.ops.nms(orig_prediction["boxes"].cpu(), orig_prediction["scores"].cpu(), iou_thresh)
    
    final_prediction = orig_prediction
    final_prediction['boxes'] = final_prediction['boxes'].cpu()[keep]
    final_prediction['scores'] = final_prediction['scores'].cpu()[keep]
    final_prediction['labels'] = final_prediction['labels'].cpu()[keep]
    
    return final_prediction


#function to convert tensor back to PIL img
def torch_to_pil(img):
    return torchtrans.ToPILImage()(img).convert('RGB')

# %%
# pick one image from the test set
img, target = dataset_test[4]
# put the model in evaluation mode
model.eval()
with torch.no_grad():
  prediction = model([img.to(device)])[0]

nms_prediction = apply_nms(prediction, iou_thresh=0.01)
num_predictions = len(nms_prediction['boxes'])

print(f'Neutrophil count: {num_predictions}\n')
print('MODEL OUTPUT\n')
plot_img_box(torch_to_pil(img), prediction)
# Out:
# Neutrophil count: 6
#
# MODEL OUTPUT

# %% [markdown]
# **SAVE MODEL**
# Make sure to add [filename].pt to the end of SAVE_PATH

# %%
SAVE_PATH  = "D:/Abdallah/Venvs/tvenv/notebook/saved_models/fasterRCNN_resnet50_v2.pt"
torch.save(model, SAVE_PATH)
